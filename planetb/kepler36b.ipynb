# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pickle

from scipy.interpolate import LinearNDInterpolator as interpnd
from scipy.interpolate import interp2d, griddata

# %%
ls *.pkl
# Out:
# FinalMp.pkl  FinalRp.pkl  InitialKH.pkl  InitialMP.pkl

# %% [markdown]
# Each of these final arrays has four dimensions: Core mass, core radius, initial total mass, planet entropy.

# %%
mass = pickle.load(open('FinalMp.pkl'))
radius = pickle.load(open('FinalRp.pkl'))

initial_entropy = np.log10(pickle.load(open('InitialKH.pkl'))+0.01)
initial_mass = pickle.load(open('InitialMP.pkl'))
core_mass_grid = np.linspace(3.8, 5.2, 16)
core_radius_grid = np.linspace(1.39, 1.58, 16)

for i in range(0,16):
    initial_mass[i,:,:,:]=np.log10((initial_mass[i,:,:,:]-core_mass_grid[i]*5.97219e27)/(core_mass_grid[i]*5.97219e27)+1e-10)
initial_mass[np.isnan(initial_mass)]=0.0

# %%
print initial_mass
# Out:
# [[[[-0.15832071 -0.15833339 -0.15834874 ...,  0.          0.          0.        ]
#    [-0.18181985 -0.18183296 -0.18184898 ...,  0.          0.          0.        ]
#    [-0.20526236 -0.20527575 -0.20529257 ...,  0.          0.          0.        ]
#    ...,
#    [-1.65036986 -1.65038014 -1.65039301 ...,  0.          0.          0.        ]
#    [-1.67488731 -1.67489756 -1.67491038 ...,  0.          0.          0.        ]
#    [-1.69940545 -1.69941557 -1.69942835 ...,  0.          0.          0.        ]]
#
#   [[-0.15676838 -0.15678107 -0.15679647 ...,  0.          0.          0.        ]
#    [-0.18018144 -0.1801946  -0.18021063 ...,  0.          0.          0.        ]
#    [-0.20473102 -0.20474449 -0.20476136 ...,  0.          0.          0.        ]
#    ...,
#    [-1.65062027 -1.65063078 -1.65064407 ...,  0.          0.          0.        ]
#    [-1.67515197 -1.67516244 -1.67517557 ...,  0.          0.          0.        ]
#    [-1.69968508 -1.69969552 -1.6997086  ...,  0.          0.          0.        ]]
#
#   [[-0.1602     -0.16021284 -0.16022838 ...,  0.          0.          0.        ]
#    [-0.17977978 -0.17979301 -0.17980909 ...,  0.          0.          0.        ]
#    [-0.20430604 -0.2043196  -0.20433651 ...,  0.          0.          0.        ]
#    ...,
#    [-1.6504112  -1.65042207 -1.65043567 ...,  0.          0.          0.        ]
#    [-1.67493044 -1.67494116 -1.67495471 ...,  0.          0.          0.        ]
#    [-1.69945037 -1.69946105 -1.69947446 ...,  0.          0.          0.        ]]
#
#   ...,
#   [[-0.15897014 -0.15898344 -0.15900019 ...,  0.          0.          0.        ]
#    [-0.18250582 -0.18251969 -0.18253701 ...,  0.          0.          0.        ]
#    [-0.20598664 -0.20600121 -0.20601909 ...,  0.          0.          0.        ]
#    ...,
#    [-1.65068355 -1.65069721 -1.65071449 ...,  0.          0.          0.        ]
#    [-1.67521514 -1.67522871 -1.67524592 ...,  0.          0.          0.        ]
#    [-1.69974806 -1.69976161 -1.6997787  ...,  0.          0.          0.        ]]
#
#   [[-0.15517899 -0.15519231 -0.15520907 ...,  0.          0.          0.        ]
#    [-0.17970101 -0.17971487 -0.17973225 ...,  0.          0.          0.        ]
#    [-0.20422298 -0.20423755 -0.20425553 ...,  0.          0.          0.        ]
#    ...,
#    [-1.
...,  0.          0.          0.        ]
#    ...,
#    [-1.65036737 -1.65037177 -1.65037726 ...,  0.          0.          0.        ]
#    [-1.67489354 -1.67489793 -1.6749034  ...,  0.          0.          0.        ]
#    [-1.69942075 -1.69942512 -1.69943059 ...,  0.          0.          0.        ]]
#
#   [[-0.15834508 -0.15834929 -0.15835446 ...,  0.          0.          0.        ]
#    [-0.18184789 -0.18185226 -0.18185765 ...,  0.          0.          0.        ]
#    [-0.20529461 -0.20529912 -0.20530469 ...,  0.          0.          0.        ]
#    ...,
#    [-1.65023756 -1.65024207 -1.65024773 ...,  0.          0.          0.        ]
#    [-1.67475606 -1.67476055 -1.67476616 ...,  0.          0.          0.        ]
#    [-1.69927513 -1.69927962 -1.69928522 ...,  0.          0.          0.        ]]
#
#   [[-0.15816558 -0.15816981 -0.15817499 ...,  0.          0.          0.        ]
#    [-0.18165842 -0.18166282 -0.18166824 ...,  0.          0.          0.        ]
#    [-0.20509465 -0.20509919 -0.20510478 ...,  0.          0.          0.        ]
#    ...,
#    [-1.65053835 -1.650543   -1.6505488  ...,  0.          0.          0.        ]
#    [-1.67507418 -1.67507878 -1.67508457 ...,  0.          0.          0.        ]
#    [-1.6996116  -1.6996162  -1.69962194 ...,  0.          0.          0.        ]]]]

# %%
def mr_get(core_mass, core_radius, initial_mtot, initial_ent):
    
    if core_mass > core_mass_grid[-1] or \
        core_radius > core_radius_grid[-1] or \
        core_mass < core_mass_grid[0] or \
        core_radius < core_radius_grid[0]:
            return np.nan, np.nan
    
    mass_bin = np.digitize(np.atleast_1d(core_mass), core_mass_grid)[0]
    radius_bin = np.digitize(np.atleast_1d(core_radius), core_radius_grid)[0]
    
    mass_ilo = mass_bin - 1
    mass_ihi = mass_bin
    
    radius_ilo = radius_bin - 1
    radius_ihi = radius_bin

    #fns = []
    box_points = []
    box_mass_values = []
    box_radius_values = []
    for mi in [mass_ilo, mass_ihi]:
        for ri in [radius_ilo, radius_ihi]:            
            mass_slice = mass[mi, ri, :, :]
            radius_slice = radius[mi, ri, :, :]
            ent_grid = initial_entropy[mi, ri, :, :]
            minit_grid = initial_mass[mi, ri, :, :]
            points = np.array([ent_grid.ravel(),minit_grid.ravel()]).T

            mass_vals = mass_slice.ravel()
            mass_fn = interpnd(points, mass_vals, rescale=True)
            
            radius_vals = radius_slice.ravel()
            radius_fn = interpnd(points, radius_vals, rescale=True)

            box_points.append([core_mass_grid[mi],
                               core_radius_grid[ri]])
            box_mass_values.append([mass_fn(initial_ent, initial_mtot)])
            box_radius_values.append([radius_fn(initial_ent, initial_mtot)])
    
    box_points = np.array(box_points)
    box_mass_values = np.array(box_mass_values)
    box_radius_values = np.array(box_radius_values)
    
    return (griddata(box_points, box_mass_values, [core_mass, core_radius])[0][0],
            griddata(box_points, box_radius_values, [core_mass, core_radius])[0][0])

# %%
np.digitize([11],core_mass_grid)
# Out:
# array([16])

# %%
mr_get(4,1.581,np.log10(0.1),np.log10(1e7))
# Out:
# (nan, nan)

# %%
kep36_mass = 4.45 * 5.97e27
kep36_radius = 1.486 * 6.4e8
kep36_mass_err = 0.1 * kep36_mass
kep36_radius_err = 0.01 * kep36_radius

def loglike(p):
    mod_m, mod_r  = mr_get(*p)
    
    lnlike = (-0.5*((kep36_mass - mod_m)**2/kep36_mass_err**2.0) +
            -0.5*((kep36_radius - mod_r)**2/kep36_radius_err**2.0))
    
    if np.isnan(lnlike):
        lnlike = -np.inf

    return lnlike

# %%
loglike((4.45,1.581,np.log10(0.02),np.log10(1e7)))
# Out:
# -inf

# %%
from scipy.optimize import fmin

fmin(loglike, (7.73010527e+00,   1.97766086e+00,   5.08741816e+28,
         1.01441188e+07))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 235
#          Function evaluations: 465
# array([  7.57953042e+00,   2.05428086e+00,   5.44916243e+28,
#          1.04064348e+07])

# %%
mr_get(,   2.05428086e+00,   5.44916243e+28,
         1.04064348e+07)
# Out:
# (4.823759998068243e+28, 2354559999.6920738)

# %%
kep36_mass, kep36_radius
# Out:
# (2.65665e+28, 951040000.0)

# %%
7.76*5.97e27/(4./3*np.pi*(2.05*6.4e8)**3.0)
# Out:
# 4.8971785430393595

# %%
import emcee

# %%
ndim, nwalkers = 4, 200
p0 = [4.45,   1.486,   np.log10(0.03),
         np.log10(1.04064348e+07)]
new_p0 = np.array([p0*(1 + np.random.rand(ndim)*.1) for i in range(nwalkers)])
sampler = emcee.EnsembleSampler(nwalkers, ndim, loglike, threads=8)
sampler.run_mcmc(new_p0, 50)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-15-57488e7e110d> in <module>()
#       3          np.log10(1.04064348e+07)]
#       4 new_p0 = np.array([p0*(1 + np.random.rand(ndim)*.1) for i in range(nwalkers)])
# ----> 5 sampler = emcee.EnsembleSampler(nwalkers, ndim, loglike, threads=8)
#       6 sampler.run_mcmc(new_p0, 50)
#
# /home/jowen/anaconda/lib/python2.7/site-packages/emcee/ensemble.pyc in __init__(self, nwalkers, dim, lnpostfn, a, args, kwargs, postargs, threads, pool, live_dangerously, runtime_sortingfn)
#     105
#     106         if self.threads > 1 and self.pool is None:
# --> 107             self.pool = InterruptiblePool(self.threads)
#     108
#     109     def clear_blobs(self):
#
# /home/jowen/anaconda/lib/python2.7/site-packages/emcee/interruptible_pool.pyc in __init__(self, processes, initializer, initargs, **kwargs)
#      72         new_initializer = functools.partial(_initializer_wrapper, initializer)
#      73         super(InterruptiblePool, self).__init__(processes, new_initializer,
# ---> 74                                                 initargs, **kwargs)
#      75
#      76     def map(self, func, iterable, chunksize=None):
#
# /home/jowen/anaconda/lib/python2.7/multiprocessing/pool.pyc in __init__(self, processes, initializer, initargs, maxtasksperchild)
#     157         self._processes = processes
#     158         self._pool = []
# --> 159         self._repopulate_pool()
#     160
#     161         self._worker_handler = threading.Thread(
#
# /home/jowen/anaconda/lib/python2.7/multiprocessing/pool.pyc in _repopulate_pool(self)
#     221             w.name = w.name.replace('Process', 'PoolWorker')
#     222             w.daemon = True
# --> 223             w.start()
#     224             debug('added worker')
#     225
#
# /home/jowen/anaconda/lib/python2.7/multiprocessing/process.pyc in start(self)
#     128         else:
#     129             from .forking import Popen
# --> 130         self._popen = Popen(self)
#     131         _current_process._children.add(self)
#     132
#
# /home/jowen/anaconda/lib/python2.7/multiprocessing/forking.pyc in __init__(self, process_obj)
#     119             self.returncode = None
#     120
# --> 121             self.pid = os.fork()
#     122             if self.pid == 0:
#     123                 if 'random' in sys.modules:
#
# OSError: [Errno 12] Cannot allocate memory

# %%
import triangle

# %%
triangle.corner(sampler.flatchain);

# %%
plt.hist((sampler.flatchain[:,2]),bins=30);
